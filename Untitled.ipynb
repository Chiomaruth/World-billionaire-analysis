# %% [markdown]
# # Tittle: Worldwide Billionaire Analysis Using Python

# %%
# importation of the package
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# import the data into dataframe
df = pd.read_csv("Billionaire.csv")

# %% [markdown]
# # Data Accessing

# %%
# print the first five rows
df.head()
# Out:
#                        Name NetWorth        Country         Source  Rank  \
# 0                Jeff Bezos   $177 B  United States         Amazon     1
# 1                 Elon Musk   $151 B  United States  Tesla, SpaceX     2
# 2  Bernard Arnault & family   $150 B         France           LVMH     3
# 3                Bill Gates   $124 B  United States      Microsoft     4
# 4           Mark Zuckerberg    $97 B  United States       Facebook     5
#
#     Age          Industry
# 0  57.0        Technology
# 1  49.0        Automotive
# 2  72.0  Fashion & Retail
# 3  65.0        Technology
# 4  36.0        Technology

# %%
# print the last five rows
df.tail()
# Out:
#                    Name NetWorth Country        Source  Rank   Age  \
# 2750  Daniel Yong Zhang     $1 B   China    e-commerce  2674  49.0
# 2751      Zhang Yuqiang     $1 B   China    Fiberglass  2674  65.0
# 2752      Zhao Meiguang     $1 B   China   gold mining  2674  58.0
# 2753     Zhong Naixiong     $1 B   China  conglomerate  2674  58.0
# 2754    Zhou Wei family     $1 B   China      Software  2674  54.0
#
#              Industry
# 2750       Technology
# 2751    Manufacturing
# 2752  Metals & Mining
# 2753      Diversified
# 2754       Technology

# %%
# print the first 10 rows
df.head(10)
# Out:
#                        Name NetWorth        Country              Source  Rank  \
# 0                Jeff Bezos   $177 B  United States              Amazon     1
# 1                 Elon Musk   $151 B  United States       Tesla, SpaceX     2
# 2  Bernard Arnault & family   $150 B         France                LVMH     3
# 3                Bill Gates   $124 B  United States           Microsoft     4
# 4           Mark Zuckerberg    $97 B  United States            Facebook     5
# 5            Warren Buffett    $96 B  United States  Berkshire Hathaway     6
# 6             Larry Ellison    $93 B  United States            software     7
# 7                Larry Page  $91.5 B  United States              Google     8
# 8               Sergey Brin    $89 B  United States              Google     9
# 9             Mukesh Ambani  $84.5 B          India         diversified    10
#
#     Age               Industry
# 0  57.0             Technology
# 1  49.0             Automotive
# 2  72.0       Fashion & Retail
# 3  65.0             Technology
# 4  36.0             Technology
# 5  90.0  Finance & Investments
# 6  76.0             Technology
# 7  48.0             Technology
# 8  47.0             Technology
# 9  63.0            Diversified

# %%
# to print the summary of our data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2755 entries, 0 to 2754
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      2755 non-null   object
#  1   NetWorth  2755 non-null   object
#  2   Country   2755 non-null   object
#  3   Source    2755 non-null   object
#  4   Rank      2755 non-null   int64
#  5   Age       2676 non-null   float64
#  6   Industry  2755 non-null   object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 172.2+ KB

# %% [markdown]
# # the dataset consist of 2755 entries in rows and seven columns.some of the columns contain missing values which will be dealth with later on.five of the colmn are object datatype,one is int while one is float datatype.

# %%
# to check for duplicate
df.duplicated().sum()
# Out:
# 0

# %%
 # check for missing value
df.isna().sum()
# Out:
# Name         0
# NetWorth     0
# Country      0
# Source       0
# Rank         0
# Age         79
# Industry     0
# dtype: int64

# %% [markdown]
# # this means that we do not have any missing values on the columns with 0,but only on the age column where we have 79
# # missing values.

# %%
# to show the columns in the dataset
df.columns
# Out:
# Index(['Name', 'NetWorth', 'Country', 'Source', 'Rank', 'Age', 'Industry'], dtype='object')

# %%
# to check the dimension of the dataset
df.shape
# Out:
# (2755, 7)

# %%
# to check the statistics summary
df.describe()
# Out:
#               Rank          Age
# count  2755.000000  2676.000000
# mean   1345.663521    63.113602
# std     772.669811    13.445153
# min       1.000000    18.000000
# 25%     680.000000    54.000000
# 50%    1362.000000    63.000000
# 75%    2035.000000    73.000000
# max    2674.000000    99.000000

# %% [markdown]
# # Data Cleaning

# %%
# drop all the duplicate records
df.drop_duplicates(inplace=True)

# %%
# to deal/treat the missing value
 to find the mean in the Age column
# Out:
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_3300\3181686767.py", line 2
#     to find the mean in the Age column
#     ^
# IndentationError: unexpected indent

# %%
df.Age
# Out:
# 0       57.0
# 1       49.0
# 2       72.0
# 3       65.0
# 4       36.0
#         ...
# 2750    49.0
# 2751    65.0
# 2752    58.0
# 2753    58.0
# 2754    54.0
# Name: Age, Length: 2755, dtype: float64

# %%
df.Age.mean()
# Out:
# 63.1136023916293

# %%
# to round it off to 2dec.pl
round(df.Age.mean(),0)
# Out:
# 63.0

# %%
# to fill the missing values in Age with mean
age_mean=round(df.Age.mean(),0)
df.Age.fillna(age_mean,inplace=True)

# %%
# to check for the most occurance countries in the dataset
df.Country.mode()
# Out:
# 0    United States
# Name: Country, dtype: object

# %%
# to check for all the countries in the dataset.
df.Country
# Out:
# 0       United States
# 1       United States
# 2              France
# 3       United States
# 4       United States
#             ...
# 2750            China
# 2751            China
# 2752            China
# 2753            China
# 2754            China
# Name: Country, Length: 2755, dtype: object

# %% [markdown]
# # Data Analysis

# %%
df
# Out:
#                           Name NetWorth        Country         Source  Rank  \
# 0                   Jeff Bezos   $177 B  United States         Amazon     1
# 1                    Elon Musk   $151 B  United States  Tesla, SpaceX     2
# 2     Bernard Arnault & family   $150 B         France           LVMH     3
# 3                   Bill Gates   $124 B  United States      Microsoft     4
# 4              Mark Zuckerberg    $97 B  United States       Facebook     5
# ...                        ...      ...            ...            ...   ...
# 2750         Daniel Yong Zhang     $1 B          China     e-commerce  2674
# 2751             Zhang Yuqiang     $1 B          China     Fiberglass  2674
# 2752             Zhao Meiguang     $1 B          China    gold mining  2674
# 2753            Zhong Naixiong     $1 B          China   conglomerate  2674
# 2754           Zhou Wei family     $1 B          China       Software  2674
#
#        Age          Industry
# 0     57.0        Technology
# 1     49.0        Automotive
# 2     72.0  Fashion & Retail
# 3     65.0        Technology
# 4     36.0        Technology
# ...    ...               ...
# 2750  49.0        Technology
# 2751  65.0     Manufacturing
# 2752  58.0   Metals & Mining
# 2753  58.0       Diversified
# 2754  54.0        Technology
#
# [2755 rows x 7 columns]

# %%
# to change the unit of the networth
fun = lambda x:  x.strip("B").strip("$").strip()
df["Networth(B)"]=df.NetWorth.apply(fun)

# %%
# drop the networth column
df.drop(columns=["NetWorth"],inplace=True)

# %%
df
# Out:
#                           Name        Country         Source  Rank   Age  \
# 0                   Jeff Bezos  United States         Amazon     1  57.0
# 1                    Elon Musk  United States  Tesla, SpaceX     2  49.0
# 2     Bernard Arnault & family         France           LVMH     3  72.0
# 3                   Bill Gates  United States      Microsoft     4  65.0
# 4              Mark Zuckerberg  United States       Facebook     5  36.0
# ...                        ...            ...            ...   ...   ...
# 2750         Daniel Yong Zhang          China     e-commerce  2674  49.0
# 2751             Zhang Yuqiang          China     Fiberglass  2674  65.0
# 2752             Zhao Meiguang          China    gold mining  2674  58.0
# 2753            Zhong Naixiong          China   conglomerate  2674  58.0
# 2754           Zhou Wei family          China       Software  2674  54.0
#
#               Industry Networth(B)
# 0           Technology         177
# 1           Automotive         151
# 2     Fashion & Retail         150
# 3           Technology         124
# 4           Technology          97
# ...                ...         ...
# 2750        Technology           1
# 2751     Manufacturing           1
# 2752   Metals & Mining           1
# 2753       Diversified           1
# 2754        Technology           1
#
# [2755 rows x 7 columns]

# %% [markdown]
# # what country has the highest number of Billionaire

# %%
# perform count of country
df.Country.value_counts().head()
# Out:
# United States    724
# China            626
# India            140
# Germany          136
# Russia           118
# Name: Country, dtype: int64

# %%
# we limit it by Top 5 Counrty
top_5_country_with_billionaire=df.Country.value_counts().head()
top_5_country_with_billionaire
# Out:
# United States    724
# China            626
# India            140
# Germany          136
# Russia           118
# Name: Country, dtype: int64

# %%
# use pandas plot to display bar plot
top_5_country_with_billionaire.plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
# if you want to use matplot to display bar plot

# %%
plt.bar(x=top_5_country_with_billionaire.index,height=top_5_country_with_billionaire.values)
plt.show()

# %%
# to use seaborn to display the bar plot

sns.barplot(x=top_5_country_with_billionaire.index,y=top_5_country_with_billionaire.values)
# to give it a title:
plt.title("top 5 countries with billionaire")
plt.ylabel("Count")
plt.xlabel("Country")
plt.show()

# %%
# use pandas plot to display pie plot
top_5_country_with_billionaire.plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='Country'>

# %%
# to check fro top 5 indusrty with the highest number of billionaire

# %%
df
# Out:
#                           Name        Country         Source  Rank   Age  \
# 0                   Jeff Bezos  United States         Amazon     1  57.0
# 1                    Elon Musk  United States  Tesla, SpaceX     2  49.0
# 2     Bernard Arnault & family         France           LVMH     3  72.0
# 3                   Bill Gates  United States      Microsoft     4  65.0
# 4              Mark Zuckerberg  United States       Facebook     5  36.0
# ...                        ...            ...            ...   ...   ...
# 2750         Daniel Yong Zhang          China     e-commerce  2674  49.0
# 2751             Zhang Yuqiang          China     Fiberglass  2674  65.0
# 2752             Zhao Meiguang          China    gold mining  2674  58.0
# 2753            Zhong Naixiong          China   conglomerate  2674  58.0
# 2754           Zhou Wei family          China       Software  2674  54.0
#
#               Industry Networth(B)
# 0           Technology         177
# 1           Automotive         151
# 2     Fashion & Retail         150
# 3           Technology         124
# 4           Technology          97
# ...                ...         ...
# 2750        Technology           1
# 2751     Manufacturing           1
# 2752   Metals & Mining           1
# 2753       Diversified           1
# 2754        Technology           1
#
# [2755 rows x 7 columns]

# %%
df.head(5)
# Out:
#                        Name        Country         Source  Rank   Age  \
# 0                Jeff Bezos  United States         Amazon     1  57.0
# 1                 Elon Musk  United States  Tesla, SpaceX     2  49.0
# 2  Bernard Arnault & family         France           LVMH     3  72.0
# 3                Bill Gates  United States      Microsoft     4  65.0
# 4           Mark Zuckerberg  United States       Facebook     5  36.0
#
#            Industry Networth(B)
# 0        Technology         177
# 1        Automotive         151
# 2  Fashion & Retail         150
# 3        Technology         124
# 4        Technology          97

# %%
Top_5_Industry_with_billionaire = df.Industry.value_counts().head()

# %%
Top_5_Industry_with_billionaire
# Out:
# Finance & Investments    371
# Technology               365
# Manufacturing            331
# Fashion & Retail         273
# Healthcare               221
# Name: Industry, dtype: int64

# %%
sns.barplot(x=Top_5_Industry_with_billionaire.index,y=Top_5_Industry_with_billionaire.values)
plt.title("top 5 Industry with billionaire")
plt.ylabel("Count")
plt.xlabel("Industry")
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2755 entries, 0 to 2754
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         2755 non-null   object
#  1   Country      2755 non-null   object
#  2   Source       2755 non-null   object
#  3   Rank         2755 non-null   int64
#  4   Age          2755 non-null   float64
#  5   Industry     2755 non-null   object
#  6   Networth(B)  2755 non-null   object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 172.2+ KB

# %%
df["Networth(B)"]=df["Networth(B)"].astype(float)

# %%
f=df.nlargest(5, "Networth(B)")[["Name","Industry","Networth(B)"]]
# this gives the highest number of rows based on the column stated.

# %%
f
# Out:
#                        Name          Industry  Networth(B)
# 0                Jeff Bezos        Technology        177.0
# 1                 Elon Musk        Automotive        151.0
# 2  Bernard Arnault & family  Fashion & Retail        150.0
# 3                Bill Gates        Technology        124.0
# 4           Mark Zuckerberg        Technology         97.0

# %%
df
# Out:
#                           Name        Country         Source  Rank   Age  \
# 0                   Jeff Bezos  United States         Amazon     1  57.0
# 1                    Elon Musk  United States  Tesla, SpaceX     2  49.0
# 2     Bernard Arnault & family         France           LVMH     3  72.0
# 3                   Bill Gates  United States      Microsoft     4  65.0
# 4              Mark Zuckerberg  United States       Facebook     5  36.0
# ...                        ...            ...            ...   ...   ...
# 2750         Daniel Yong Zhang          China     e-commerce  2674  49.0
# 2751             Zhang Yuqiang          China     Fiberglass  2674  65.0
# 2752             Zhao Meiguang          China    gold mining  2674  58.0
# 2753            Zhong Naixiong          China   conglomerate  2674  58.0
# 2754           Zhou Wei family          China       Software  2674  54.0
#
#               Industry  Networth(B)
# 0           Technology        177.0
# 1           Automotive        151.0
# 2     Fashion & Retail        150.0
# 3           Technology        124.0
# 4           Technology         97.0
# ...                ...          ...
# 2750        Technology          1.0
# 2751     Manufacturing          1.0
# 2752   Metals & Mining          1.0
# 2753       Diversified          1.0
# 2754        Technology          1.0
#
# [2755 rows x 7 columns]

# %% [markdown]
# # to find the relationship between Industry and Networth

# %%
df
# Out:
#                           Name        Country         Source  Rank   Age  \
# 0                   Jeff Bezos  United States         Amazon     1  57.0
# 1                    Elon Musk  United States  Tesla, SpaceX     2  49.0
# 2     Bernard Arnault & family         France           LVMH     3  72.0
# 3                   Bill Gates  United States      Microsoft     4  65.0
# 4              Mark Zuckerberg  United States       Facebook     5  36.0
# ...                        ...            ...            ...   ...   ...
# 2750         Daniel Yong Zhang          China     e-commerce  2674  49.0
# 2751             Zhang Yuqiang          China     Fiberglass  2674  65.0
# 2752             Zhao Meiguang          China    gold mining  2674  58.0
# 2753            Zhong Naixiong          China   conglomerate  2674  58.0
# 2754           Zhou Wei family          China       Software  2674  54.0
#
#               Industry  Networth(B)
# 0           Technology        177.0
# 1           Automotive        151.0
# 2     Fashion & Retail        150.0
# 3           Technology        124.0
# 4           Technology         97.0
# ...                ...          ...
# 2750        Technology          1.0
# 2751     Manufacturing          1.0
# 2752   Metals & Mining          1.0
# 2753       Diversified          1.0
# 2754        Technology          1.0
#
# [2755 rows x 7 columns]

# %%
df.groupby("Industry").agg({"Networth(B)":"sum"})
# Out:
#                             Networth(B)
# Industry
# Automotive                        467.5
# Construction & Engineering        125.1
# Diversified                       868.1
# Energy                            452.6
# Fashion & Retail                 1697.6
# Finance & Investments            1527.9
# Food & Beverage                  1029.9
# Gambling & Casinos                134.0
# Healthcare                        790.7
# Logistics                         145.8
# Manufacturing                    1119.9
# Media & Entertainment             481.3
# Metals & Mining                   431.4
# Real Estate                       815.8
# Service                           248.7
# Sports                             81.7
# Technology                       2456.7
# Telecom                           209.4

# %%
# to sort by value in ascending order
df.groupby("Industry").agg({"Networth(B)":"sum"}).sort_values(by="Networth(B)",ascending=False)
# Out:
#                             Networth(B)
# Industry
# Technology                       2456.7
# Fashion & Retail                 1697.6
# Finance & Investments            1527.9
# Manufacturing                    1119.9
# Food & Beverage                  1029.9
# Diversified                       868.1
# Real Estate                       815.8
# Healthcare                        790.7
# Media & Entertainment             481.3
# Automotive                        467.5
# Energy                            452.6
# Metals & Mining                   431.4
# Service                           248.7
# Telecom                           209.4
# Logistics                         145.8
# Gambling & Casinos                134.0
# Construction & Engineering        125.1
# Sports                             81.7

# %%
# to set it to top 10
y = df.groupby("Industry").agg({"Networth(B)":"sum"}).sort_values(by="Networth(B)",ascending=False).head(10)

# %%
y = df.groupby("Industry").agg({"Networth(B)":"sum"}).sort_values(by="Networth(B)",ascending=False).head(10)
sns.barplot(x=y.index, y=y.values.flatten())
plt.xticks(rotation=35)
plt.show()
